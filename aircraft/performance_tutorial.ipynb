# %%
""" A simple aircraft performance model to be used as GPkit tutorial"""
from gpkit import Variable, Model
from gpkit.tools import te_exp_minus1
import numpy as np

# Free Variables
b      = Variable('b', 'm', 'Wing span')
CD     = Variable('C_D', '-', 'Drag coefficient')
CL     = Variable('C_L', '-', 'Lift coefficient')
LD_la  = Variable('\\frac{L}{D}_{land}', '-', 'Lift-to-drag in final descent')
M      = Variable('M', '-', 'Mach number')
Mdd    = Variable('M_{dd}', '-', 'Drag divergence Mach number')
R      = Variable('R', 'nautical_miles', 'Range')
S      = Variable('S', 'm^2', 'Wing reference area')
s_l    = Variable('s_L', 'm', 'Total landing distance')
s_l_gr = Variable('s_{L_{gr}}', 'm', 'Ground roll distance (landing)')
s_l_oc = Variable('s_{L_{oc}}', 'm' , 'Obstacle clearance distance (landing)')
s_t    = Variable('s_{TO}', 'm', 'Total takeoff distance')
s_t_gr = Variable('s_{TO_{gr}}', 'm', 'Ground roll distance (takeoff)')
T      = Variable('T', 'N', 'Thrust')
T_t    = Variable('T_{TO}', 'N', 'Takeoff thrust')
V      = Variable('V', 'knots', 'Velocity')
Vst    = Variable('V_{stall}', 'm/s', 'Stall speed')
W      = Variable('W', 'lbf', 'Initial gross weight')
W_e    = Variable('W_e', 'lbf', 'Operating empty weight')
W_fuel = Variable('W_{fuel}', 'lbf', 'Fuel weight')
z_bre  = Variable('z_{bre}', '-', 'Breguet parameter')

# Fixed Parameters
a      = Variable('a', 300, 'm/s', 'Speed of sound at 33,000 ft')
AR     = Variable('AR', 11 , '-', 'Aspect Ratio')
bmax   = Variable('b_{max}', 36, 'm', 'Gate constraint')
cosL   = Variable('\\cos(\\Lambda)', np.cos(25*np.pi/180), '-',
                  'Cosine of quarter chord sweep')
CD0    = Variable('CD0', 0.02, '-', 'Parasitic drag coefficient')
CDl    = Variable('C_D_{land}', 0.08, '-',
                  'Drag coefficient in landing configuration')
CLmaxt = Variable('C_{L_{max}}', 2.0, '-', 'Max lift coefficient (takeoff)')
CLmaxl = Variable('C_{L_{max}}', 3.0, '-', 'Max lift coefficient (landing)')
e      = Variable('e', 0.8, '-', 'Oswald efficiency factor')
f_str  = Variable('f_{struct}', 0.5, '-', 'Structural weight fraction')
h_oc   = Variable('h_{oc}', 50, 'ft', 'Obstacle clearance height (landing)')
k      = Variable('\\kappa', 0.95, '-',
                  'Supercritical airfoil technology factor')
l_rw   = Variable('l_{rw}', 5000, 'ft', 'Runway Length (DCA)')
mu_r   = Variable('\\mu_r', 0.4, '-', 'Rolling friction coefficient')
s_t_oc = Variable('s_{TO_{oc}}', 200, 'm',
                  'Obstacle clearance distance (takeoff)')
tau    = Variable('\\tau', 0.13, '-', 'Wing thickness-to-chord ratio')
T_max  = Variable('T_{max}', 1E6, 'N', 'Maximum thrust')
TSFC   = Variable('TSFC', 0.307, 'lb/lbf/hr',
                  'Thrust specific fuel consumption')
Vstmax = Variable('V_{stall_{max}}', 55, 'm/s', 'Max allowable stall speed')
W_pay  = Variable('W_{pay}', 40000, 'lbf', 'Payload weight')

# Constants
g      = Variable('g', 9.81, 'm/s^2', 'Gravitational acceleration')
rho    = Variable('\\rho', 0.4, 'kg/m^3', 'Air density at 33,000 ft')
rho_sl = Variable('\\rho_{SL}', 1.225, 'kg/m^3', 'Air density at sea level')

# Model
objective = 1/R  # Maximize range

constraints = [# Weight buildup
               W >= W_e + W_pay + W_fuel,
               W_e >= f_str*W,

               # Breguet range
               R <= z_bre*CL/CD*V/(TSFC*g),
               # Taylor series expansion of exp(z_bre) - 1
               W_fuel/W_e >= te_exp_minus1(z_bre, nterm=3),

               # Wing geometry
               AR == b**2/S,
               b <= bmax,

               # Steady level flight
               W == 0.5*rho*V**2*S*CL,
               T == 0.5*rho*V**2*S*CD,
               T <= T_max,

               # Drag buildup
               CD >= CD0 + CL**2/(np.pi*e*AR),

               # Speed limited by compressible drag rise
               M == V/a,
               M <= Mdd,
               # Korn equation
               Mdd + tau/cosL**2 + CL/(10*cosL**3) <= k/cosL, 

               # Takeoff
               # Assumes a lift off velocity of 1.2*Vstall (1.44 = 1.2^2)
               s_t_gr >= 1.44*W**2/(g*rho_sl*S*CLmaxt*T_t),
               s_t >= s_t_gr + s_t_oc,
               s_t <= l_rw,
               T_t <= T_max,

               # Landing
               W <= 0.5*rho_sl*Vst**2*S*CLmaxl,
               Vst <= Vstmax,
               s_l_oc >= h_oc*LD_la, # assumes half fuel weight
               LD_la >= (W_e + 0.5*W_fuel)/(0.5*rho*(1.3*Vst)**2*S*CDl),
               s_l_gr == 1.69*W**2/(g*rho_sl*S*CLmaxl*mu_r*W), # conservative
               s_l >= s_l_oc + s_l_gr,
               1.67*s_l <= l_rw, # FAR 25.125

              ]

m = Model(objective, constraints)
m.solve()
# Out:
# Using solver 'mosek'
# Solving for 21 variables.
# Solving took 0.0189 seconds.
#
# Cost
# ----
#  0.0001921 [1/nmi]
#
# Free Variables
# --------------
#                C_D : 0.02667           Drag coefficient
#                C_L : 0.4293            Lift coefficient
#                  M : 0.7283            Mach number
#             M_{dd} : 0.7283            Drag divergence Mach number
#                  R : 5205       [nmi]  Range
#                  S : 117.8      [m**2] Wing reference area
#                  T : 3e+04      [N]    Thrust
#             T_{TO} : 1e+06      [N]    Takeoff thrust
#                  V : 424.7      [kt]   Velocity
#          V_{stall} : 55         [m/s]  Stall speed
#                  W : 1.086e+05  [lbf]  Initial gross weight
#                W_e : 5.429e+04  [lbf]  Operating empty weight
#           W_{fuel} : 1.429e+04  [lbf]  Fuel weight
# \frac{L}{D}_{land} : 28.36             Lift-to-drag in final descent
#                  b : 36         [m]    Wing span
#                s_L : 912.6      [m]    Total landing distance
#         s_{L_{gr}} : 480.4      [m]    Ground roll distance (landing)
#         s_{L_{oc}} : 432.2      [m]    Obstacle clearance distance (landing)
#        s_{TO_{gr}} : 118.6      [m]    Ground roll distance (takeoff)
#             s_{TO} : 1524       [m]    Total takeoff distance
#            z_{bre} : 0.2338            Breguet parameter
#
# Constants
# ---------
#              AR : 11                  Aspect Ratio
#             CD0 : 0.02                Parasitic drag coefficient
#      C_D_{land} : 0.08                Drag coefficient in landing configuration
#     C_{L_{max}} : 3                   Max lift coefficient (landing)
#     C_{L_{max}} : 2                   Max lift coefficient (takeoff)
#            TSFC : 0.307   [lb/hr/lbf] Thrust specific fuel consumption
#         T_{max} : 1e+06   [N]         Maximum thrust
# V_{stall_{max}} : 55      [m/s]       Max allowable stall speed
#         W_{pay} : 4e+04   [lbf]       Payload weight
#   \cos(\Lambda) : 0.9063              Cosine of quarter chord sweep
#          \kappa : 0.95                Supercritical airfoil technology factor
#           \mu_r : 0.4                 Rolling friction coefficient
#            \rho : 0.4     [kg/m**3]   Air density at 33,000 ft
#       \rho_{SL} : 1.225   [kg/m**3]   Air density at sea level
#            \tau : 0.13                Wing thickness-to-chord ratio
#               a : 300     [m/s]       Speed of sound at 33,000 ft
#         b_{max} : 36      [m]         Gate constraint
#               e : 0.8                 Oswald efficiency factor
#      f_{struct} : 0.5                 Structural weight fraction
#               g : 9.81    [m/s**2]    Gravitational acceleration
#          h_{oc} : 50      [ft]        Obstacle clearance height (landing)
#          l_{rw} : 5000    [ft]        Runway Length (DCA)
#     s_{TO_{oc}} : 200     [m]         Obstacle clearance distance (takeoff)
#
# Sensitivities
# -------------
#      f_{struct} : 4.829   Structural weight fraction
#         W_{pay} : 2.099   Payload weight
#              AR : 1.849   Aspect Ratio
#          h_{oc} : 1.231   Obstacle clearance height (landing)
#            TSFC : 1       Thrust specific fuel consumption
#             CD0 : 0.75    Parasitic drag coefficient
#               e : -0.25   Oswald efficiency factor
#               g : -0.3681 Gravitational acceleration
#            \rho : -0.7306 Air density at 33,000 ft
#      C_D_{land} : -1.231  Drag coefficient in landing configuration
#           \mu_r : -1.368  Rolling friction coefficient
#     C_{L_{max}} : -1.368  Max lift coefficient (landing)
#       \rho_{SL} : -1.368  Air density at sea level
# V_{stall_{max}} : -2.461  Max allowable stall speed
#          l_{rw} : -2.599  Runway Length (DCA)
#         b_{max} : -4.197  Gate constraint
# {'constants': {T_{max}: array(1000000.0),
#   \tau: array(0.13),
#   s_{TO_{oc}}: array(200),
#   \mu_r: array(0.4),
#   a: array(300),
#   AR: array(11),
#   b_{max}: array(36),
#   l_{rw}: array(5000),
#   \cos(\Lambda): array(0.9063077870366499),
#   C_D_{land}: array(0.08),
#   CD0: array(0.02),
#   C_{L_{max}}: array(2.0),
#   C_{L_{max}}: array(3.0),
#   \kappa: array(0.95),
#   e: array(0.8),
#   f_{struct}: array(0.5),
#   h_{oc}: array(50),
#   TSFC: array(0.307),
#   V_{stall_{max}}: array(55),
#   W_{pay}: array(40000),
#   g: array(9.81),
#   \rho: array(0.4),
#   \rho_{SL}: array(1.225)},
#  'cost': array(0.00019212874187822412),
#  'freevariables': {b: array(35.99999999819136),
#   C_D: array(0.026666666704877003),
#   C_L: array(0.4293096435469812),
#   R: array(5204.84330444873),
#   \frac{L}{D}_{land}: array(28.35659371164969),
#   M: array(0.728348025399375),
#   M_{dd}: array(0.728348025399375),
#   S: array(117.81818178925161),
#   s_L: array(912.5748502994016),
#   s_{L_{gr}}: array(480.4203618758955),
#   s_{L_{oc}}: array(432.15448816554147),
#   s_{TO}: array(1524.0000000000007),
#   s_{TO_{gr}}: array(118.62652367869016),
#   T: array(30000.704189046268),
#   T_{TO}: array(999999.9999999995),
#   V: array(424.73858932576945),
#   V_{stall}: array(55.000000000000014),
#   W: array(108579.27654703529),
#   W_e: array(54289.63827351764),
#   W_{fuel}: array(14289.638292215493),
#   z_{bre}: array(0.23376028875473776)},
#  'localmodel': 1.61e+05*AR**1.8*CD0**0.75*C_D_{land}**-1.2*C_{L_{max}}**-1.4*TSFC*V_{stall_{max}}**-2.5*W_{pay}**2.1*\mu_r**-1.4*\rho**-0.73*\rho_{SL}**-1.4*b_{max}**-4.2*e**-0.25*f_{struct}**4.8*g**-0.37*h_{oc}**1.2*l_{rw}**-2.6,
#  'sensitivities': {'monomials': array([  1.00000000e+00,   2.84847619e+00,   7.49750704e-01,
#            2.09872549e+00,   4.82886665e+00,   1.00000000e+00,
#            9.26824137e-02,   7.22182268e-03,   7.92969705e-01,
#            2.09872549e+00,   0.00000000e+00,   4.19745098e+00,
#            0.00000000e+00,   4.99999998e-01,   0.00000000e+00,
#            6.02466905e-11,   6.02466905e-11,   2.50000001e-01,
#            7.49999999e-01,   0.00000000e+00,   4.13681507e-09,
#            4.13681507e-09,   8.54142464e-10,   4.79203456e-10,
#            4.13681507e-09,   1.22232297e-10,   1.45937408e-10,
#            1.22232297e-10,   2.68169705e-10,   1.22232297e-10,
#            6.91798175e-10,   2.46127950e+00,   1.23063975e+00,
#            1.43123237e-01,   1.08751651e+00,   0.00000000e+00,
#            1.36808574e+00,   1.23063975e+00,   1.36808574e+00,
#            2.59872549e+00]),
#   'posynomials': array([  1.00000000e+00,   5.69695239e+00,   4.82886665e+00,
#            1.00000000e+00,   8.92873941e-01,   2.09872549e+00,
#            0.00000000e+00,   4.19745098e+00,   0.00000000e+00,
#            4.99999998e-01,   0.00000000e+00,   6.02466905e-11,
#            6.02466905e-11,   1.00000000e+00,   0.00000000e+00,
#            4.13681507e-09,   4.13681507e-09,   5.47016099e-09,
#            1.22232297e-10,   2.68169705e-10,   2.68169705e-10,
#            1.22232297e-10,   6.91798175e-10,   2.46127950e+00,
#            1.23063975e+00,   1.23063975e+00,   0.00000000e+00,
#            1.36808574e+00,   2.59872549e+00,   2.59872549e+00]),
#   'variables': {b: array(0.0),
#    C_D: array(8.881784197001252e-16),
#    C_L: array(3.8488546591048376e-11),
#    R: array(0.0),
#    \frac{L}{D}_{land}: array(-3.848854568389015e-11),
#    M: array(0.0),
#    M_{dd}: array(0.0),
#    T_{max}: array(-1.824789873893386e-10),
#    S: array(-1.5395551500319016e-10),
#    s_L: array(0.0),
#    s_{L_{gr}}: array(0.0),
#    s_{L_{oc}}: array(0.0),
#    \tau: array(8.541424639854371e-10),
#    s_{TO}: array(0.0),
#    s_{TO_{gr}}: array(0.0),
#    T: array(0.0),
#    T_{TO}: array(0.0),
#    s_{TO_{oc}}: array(1.4593740820872682e-10),
#    V: array(-5.0592453240428644e-17),
#    V_{stall}: array(0.0),
#    W: array(2.6942159614407046e-10),
#    W_e: array(6.661338147750939e-16),
#    W_{fuel}: array(-3.848879548407069e-11),
#    \mu_r: array(-1.368085739830419),
#    z_{bre}: array(1.92443505575568e-10),
#    a: array(-4.13681507417995e-09),
#    AR: array(1.848725489100481),
#    b_{max}: array(-4.1974509798889015),
#    l_{rw}: array(-2.598725487445649),
#    \cos(\Lambda): array(2.3242656989897773e-09),
#    C_D_{land}: array(-1.230639747385549),
#    CD0: array(0.7499999992162761),
#    C_{L_{max}}: array(-1.2223229691130305e-10),
#    C_{L_{max}}: array(-1.368085740522217),
#    \kappa: array(-5.470160993767755e-09),
#    e: array(-0.25000000084396967),
#    f_{struct}: array(4.828866645085551),
#    h_{oc}: array(1.2306397473470605),
#    TSFC: array(1.0),
#    V_{stall_{max}}: array(-2.4612794961546944),
#    W_{pay}: array(2.0987254900499517),
#    g: array(-0.36808573995265126),
#    \rho: array(-0.7306397494539567),
#    \rho_{SL}: array(-1.3680857406444493)}},
#  'sweepvariables': {},
#  'variables': {b: array(35.99999999819136),
#   C_D: array(0.026666666704877003),
#   C_L: array(0.4293096435469812),
#   R: array(5204.84330444873),
#   \frac{L}{D}_{land}: array(28.35659371164969),
#   M: array(0.728348025399375),
#   M_{dd}: array(0.728348025399375),
#   T_{max}: array(1000000.0),
#   S: array(117.81818178925161),
#   s_L: array(912.5748502994016),
#   s_{L_{gr}}: array(480.4203618758955),
#   s_{L_{oc}}: array(432.15448816554147),
#   \tau: array(0.13),
#   s_{TO}: array(1524.0000000000007),
#   s_{TO_{gr}}: array(118.62652367869016),
#   T: array(30000.704189046268),
#   T_{TO}: array(999999.9999999995),
#   s_{TO_{oc}}: array(200),
#   V: array(424.73858932576945),
#   V_{stall}: array(55.000000000000014),
#   W: array(108579.27654703529),
#   W_e: array(54289.63827351764),
#   W_{fuel}: array(14289.638292215493),
#   \mu_r: array(0.4),
#   z_{bre}: array(0.23376028875473776),
#   a: array(300),
#   AR: array(11),
#   b_{max}: array(36),
#   l_{rw}: array(5000),
#   \cos(\Lambda): array(0.9063077870366499),
#   C_D_{land}: array(0.08),
#   CD0: array(0.02),
#   C_{L_{max}}: array(2.0),
#   C_{L_{max}}: array(3.0),
#   \kappa: array(0.95),
#   e: array(0.8),
#   f_{struct}: array(0.5),
#   h_{oc}: array(50),
#   TSFC: array(0.307),
#   V_{stall_{max}}: array(55),
#   W_{pay}: array(40000),
#   g: array(9.81),
#   \rho: array(0.4),
#   \rho_{SL}: array(1.225)}}
