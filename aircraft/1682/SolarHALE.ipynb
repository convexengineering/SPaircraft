# %%
from solar_hale import SolarHALE
import gpkit
gpkit.settings['latex_modelname'] = False

# this notebook is for interactive controlpanel() use
# to modify the SolarHALE model, edit solar_hale.py
m = SolarHALE()
sol = m.solve()
# m.controlpanel()
# Out:
# Using solver 'cvxopt'
# Solving for 19 variables.
# Solving took 0.0644 seconds.
#
# Cost
# ----
#  41.44 [lbf]
#
# Free Variables
# --------------
#          C_D : 0.06743              Drag coefficient
#          C_L : 1.5                  Lift coefficient
#          C_f : 0.006784             wing skin friction coefficient
#     E_{batt} : 7.365e+06  [J]       Battery energy
#   P_{charge} : 179.5      [W]       Battery charging power
#     P_{oper} : 162        [W]       Aircraft operating power
#    P_{shaft} : 152        [W]       Shaft power
#           Re : 1.545e+05            Reynolds number
#            S : 3.414      [m**2]    Wing reference area
#      T_{atm} : 226.2      [K]       air temperature
#            V : 12.84      [m/s]     Cruise velocity
#            W : 41.44      [lbf]     Aircraft weight
# W_{airframe} : 10.36      [lbf]     Airframe weight
#     W_{batt} : 18.05      [lbf]     Battery weight
#    W_{solar} : 9.035      [lbf]     Solar panel weight
#         \rho : 0.4369     [kg/m**3]
#            b : 27.11      [ft]      span
#            h : 3.128e+04  [ft]      Altitude
#      t_{day} : 12         [hr]      Daylight span
#
# Constants
# ---------
#      (P/S)_{irr} : 500        [W/m**2]   Average daytime solar irradiance
#                A : 20                    aspect ratio
#        C_{L-max} : 1.5                   maximum lift coefficient
#           C_{d0} : 0.01                  non-wing drag coefficient
#         K_{wing} : 1.3                   wing form factor
#          L_{atm} : 0.0065     [K/m]      Temperature lapse rate
#          M_{atm} : 0.02896    [kg/mol]   Molar mass of dry air
#          P_{acc} : 10         [W]        Accessory power draw
#          R_{atm} : 8.314      [J/K/mol]
#        R_{earth} : 6371       [km]       Radius of earth
#           T_{sl} : 288.1      [K]        Temperature at sea level
#          V_{min} : 12         [m/s]      minimum flight velocity
#          W_{pay} : 4          [lbf]      Aircraft weight
#    \eta_{charge} : 0.95                  Battery charging efficiency
# \eta_{discharge} : 0.95                  Battery discharging efficiency
#      \eta_{prop} : 0.7                   Propulsive efficiency
#     \eta_{solar} : 0.2                   Solar cell efficiency
#              \mu : 1.5e-05    [N*s/m**2] dynamic viscosity
#     \rho_{solar} : 1.2        [kg/m**2]  Solar cell area density
# \theta_{look-up} : 5                     look up angle
#    d_{footprint} : 200        [km]       station keeping footprint diameter
#                e : 0.9                   spanwise efficiency
#     f_{airframe} : 0.25                  Airframe weight fraction
#                g : 9.81       [m/s**2]   Gravitational acceleration
#         h_{batt} : 250        [W*hr/kg]  Battery energy density
#           p_{sl} : 1.013e+05  [Pa]       Pressure at sea level
#        t_{night} : 12         [hr]       Night span
#
# Sensitivities
# -------------
#                g : 4.844    Gravitational acceleration
#        t_{night} : 3.301    Night span
#    d_{footprint} : 2.055    station keeping footprint diameter
#          L_{atm} : 1.899    Temperature lapse rate
#     f_{airframe} : 1.853    Airframe weight fraction
# \theta_{look-up} : 1.751    look up angle
#          R_{atm} : 1.628
#     \rho_{solar} : 1.616    Solar cell area density
#         K_{wing} : 0.8093   wing form factor
#          W_{pay} : 0.7155   Aircraft weight
#           C_{d0} : 0.4588   non-wing drag coefficient
#          P_{acc} : 0.2036   Accessory power draw
#              \mu : 0.1619   dynamic viscosity
#    \eta_{charge} : -0.03642 Battery charging efficiency
#     \eta_{solar} : -0.06929 Solar cell efficiency
#      (P/S)_{irr} : -0.06929 Average daytime solar irradiance
#        R_{earth} : -0.1563  Radius of earth
#           T_{sl} : -0.271   Temperature at sea level
#        C_{L-max} : -0.9084  maximum lift coefficient
#           p_{sl} : -1.628   Pressure at sea level
#          M_{atm} : -1.628   Molar mass of dry air
#                A : -1.745   aspect ratio
#                e : -1.826   spanwise efficiency
#      \eta_{prop} : -3.094   Propulsive efficiency
#         h_{batt} : -3.228   Battery energy density
# \eta_{discharge} : -3.265   Battery discharging efficiency

# %%
import numpy as np
m.substitutions.update({"d_{footprint}": ('sweep', np.linspace(100, 300, 13)),
                        "h_{batt}": ('sweep', np.linspace(150, 250, 13))})
sol = m.solve(solver="mosek", verbosity=0, skipsweepfailures=True)

# %%
# %matplotlib inline
from gpkit.interactive.plotting import contour_array
_ = contour_array(m, "d_{footprint}", "h_{batt}", ["b", "W", "C_D", "h"])
